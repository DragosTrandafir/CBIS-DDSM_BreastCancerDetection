# %% [markdown]
# # Custom CNN architecture

# %%
# Run the previous notebook to load all its classes and functions
# %run cbis_ddsm_create_ROI_dataset_classification.ipynb
# Out:
# Processing calc patients: 100%|██████████████████████████████████████████████████████| 527/527 [00:06<00:00, 86.38it/s]
# Processing calc patients: 100%|█████████████████████████████████████████████████████| 112/112 [00:01<00:00, 105.67it/s]
# Processing calc patients: 100%|█████████████████████████████████████████████████████| 527/527 [00:05<00:00, 102.52it/s]
# Processing calc patients: 100%|█████████████████████████████████████████████████████| 112/112 [00:00<00:00, 146.65it/s]
# Processing calc patients: 100%|█████████████████████████████████████████████████████| 114/114 [00:01<00:00, 113.45it/s]
# calc:
#   Train patients: 527
#   Val patients:   112
#   Test patients:  114
#   Total patients: 753
#   Overlaps: train-val=0, train-test=0, val-test=0
#   Image counts -> Train: 1265, Val: 330, Test: 277
# Processing mass patients: 100%|█████████████████████████████████████████████████████| 624/624 [00:03<00:00, 203.51it/s]
# Processing mass patients: 100%|█████████████████████████████████████████████████████| 133/133 [00:00<00:00, 217.19it/s]
# Processing mass patients: 100%|█████████████████████████████████████████████████████| 624/624 [00:02<00:00, 237.56it/s]
# Processing mass patients: 100%|█████████████████████████████████████████████████████| 133/133 [00:00<00:00, 262.72it/s]
# Processing mass patients: 100%|█████████████████████████████████████████████████████| 135/135 [00:00<00:00, 223.56it/s]
# mass:
#   Train patients: 624
#   Val patients:   133
#   Test patients:  135
#   Total patients: 892
#   Overlaps: train-val=0, train-test=0, val-test=0
#   Image counts -> Train: 1191, Val: 253, Test: 252
# Non-CLAHE shapes -> X_train: (2456, 224, 224, 1), X_val: (583, 224, 224, 1), X_test: (529, 224, 224, 1)
# CLAHE shapes -> X_train: (2456, 224, 224, 1), X_val: (583, 224, 224, 1), X_test: (529, 224, 224, 1)
# clahe
# train
# val
# test
# non clahe
# train
# val
# test

# %% [markdown]
# ### Normalize Data
# This step is important because:
# - we have features which are in a wide range (each pixels ranges from 0 to 255)
# - we have to make them matter the same to the ML model
# - prevent numerical instability
# - normal distribution assumption

# %%
print(f"Non-CLAHE shapes -> X_train_non: {X_train_non_clahe.shape}, X_val_non: {X_val_non_clahe.shape}, X_test_non: {X_test_non_clahe.shape}")
print(f"CLAHE shapes -> X_train: {X_train_clahe.shape}, X_val: {X_val_clahe.shape}, X_test: {X_test_clahe.shape}")
# Out:
# Non-CLAHE shapes -> X_train_non: (2456, 224, 224, 1), X_val_non: (583, 224, 224, 1), X_test_non: (529, 224, 224, 1)
# CLAHE shapes -> X_train: (2456, 224, 224, 1), X_val: (583, 224, 224, 1), X_test: (529, 224, 224, 1)

# %%
X_train_non_clahe = X_train_non_clahe.astype('float32') / 255.0
X_val_non_clahe   = X_val_non_clahe.astype('float32') / 255.0
X_test_non_clahe  = X_test_non_clahe.astype('float32') / 255.0

print(f"Final shapes AFTER NORMALIZATION -> X_train_non_clahe: {X_train_non_clahe.shape}, X_val_non: {X_val_non_clahe.shape}, X_test_non: {X_test_non_clahe.shape}")


X_train_clahe = X_train_clahe.astype('float32') / 255.0
X_val_clahe   = X_val_clahe.astype('float32') / 255.0
X_test_clahe  = X_test_clahe.astype('float32') / 255.0

print(f"Final shapes AFTER NORMALIZATION -> X_train: {X_train_clahe.shape}, X_val: {X_val_clahe.shape}, X_test: {X_test_clahe.shape}")
# Out:
# Final shapes AFTER NORMALIZATION -> X_train_non_clahe: (2456, 224, 224, 1), X_val_non: (583, 224, 224, 1), X_test_non: (529, 224, 224, 1)
# Final shapes AFTER NORMALIZATION -> X_train: (2456, 224, 224, 1), X_val: (583, 224, 224, 1), X_test: (529, 224, 224, 1)

# %% [markdown]
# ## CNN training

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, LeakyReLU, BatchNormalization, Conv2D, MaxPooling2D, Flatten,  Dropout, Activation
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import tensorflow as tf
from tensorflow.keras.datasets import mnist, cifar10
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import seaborn as sns
import time

# %% [markdown]
# ## Explaining some concepts that we will use later

# %% [markdown]
# ### CNNs
# - specialized NNs designed for grid-like data
# - automatically learn spacial hierarchies of features through convolution operations
# - highly effective in tasks involving visual perception

# %% [markdown]
# ### Convolutional layer
# **Convolution** is a mathematical operation where a small filter (kernel) is systematically applied across an input (such as an image) to produce a feature map that captures important local patterns like edges, textures, or more complex structures.
#
# - **number of filters** = how many different kernels does the layer apply? So we basically get **number of filters** different feature maps.
# - As we go on through the layers of the model, we may need more and more different kernels to try, because we have more intricate patterns in the images.
#
# - **kernel_size** = what is the size of the filter/kernels, helping us to detect edges like shapes, edges etc.
#
# - **activation** = the activation function used

# %% [markdown]
# ### Pooling layers
#
# A pooling layer reduces the spatial dimentions(width and height) of a feature map by summarizing regions of th input, helping to decrease computation, control overfitting, and make the network more robust to small translations
#
# Purpose:
#
# - downsampling: reduces the size of feature maps;
# - feature preservation: keeps the most important information
# - translation invariance: small changes in input data do not change the pooled output much
#
# ### Max Pooling
#
# Helps us detect the strongest activation, e.g. what feature is the most present. This way, we can detect more proeminent patterns and also improve computations.

# %% [markdown]
# ### Fully Connected Layers
#
# Learn from the high-level features extracted by convolutional and pooling layers
#
# - **dropout** - during training, turns off a percent of neurons in the Dense layer, to prevent overfitting.

# %% [markdown]
# ### ReLU Activation
# - keeps patterns of the data, also getting rid of negative values
# - neurons stuck with negative inputs stop updating (gradient = 0)
# - most popular in modern NNs

# %% [markdown]
# ### LeakyReLU
# - allows a small gradient when x < 0 → avoids dying ReLU.

# %% [markdown]
# ### Batch size
# - how many training samples the network processes before updating its weights during training. It influences both the model's performance and the computational efficiency.
# - some mostly used values are 32, 64, 128 ...
# - I chose 32 because it puts in balance the computational resources needed and the efficiency of the model

# %% [markdown]
# ### Adam Optimizer
#
# Adam (short for **Adaptive Moment Estimation**) is one of the most popular and effective optimization algorithms used to train deep learning models. Adam adapts the learning rate for each parameter individually using **first** and **second moments** of the gradients:
#
# - The **first moment** is the **mean** of the gradient (like momentum).
# - The **second moment** is the **uncentered variance** of the gradient.
#
# This helps Adam:
# - Converge faster
# - Handle sparse gradients

# %% [markdown]
# # 1. Model from article

# %% [markdown]
# This is the implementation of the custom CNN from https://www.researchgate.net/publication/344611800_Convolutional_neural_network-based_models_for_diagnosis_of_breast_cancer. Let us see what results we get on our dataset.

# %%
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

# %%
model = Sequential([
    # Input layer (grayscale images 224x224x1)
    Input(shape=(224, 224, 1)),

    # Convolutional layer: 20 filters, kernel size 5x5
    Conv2D(20, (5, 5), padding="same"),
    
    # Batch Normalization (20 channels)
    BatchNormalization(),
    
    # ReLU activation
    Activation("relu"),
    
    # MaxPooling
    MaxPooling2D(pool_size=(2, 2)),
    
    # Flatten before fully connected
    Flatten(),
    
    # Fully connected layer (let’s use 128 units)
    Dense(128, activation="relu"),
    
    # Dropout 50%
    Dropout(0.5),
    
    # Output layer with 3 classes
    Dense(2, activation="softmax")
])

# %%
# Compile
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=15,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 49s 666ms/step - accuracy: 0.6916 - loss: 12.3356 - val_accuracy: 0.7622 - val_loss: 0.5326
# Epoch 2/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 47s 667ms/step - accuracy: 0.7093 - loss: 0.6171 - val_accuracy: 0.7557 - val_loss: 0.5257
# Epoch 3/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 47s 663ms/step - accuracy: 0.6684 - loss: 0.5948 - val_accuracy: 0.7590 - val_loss: 0.5238
# Epoch 4/15
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 48s 672ms/step - accuracy: 0.6440 - loss: 0.6092 - val_accuracy: 0.7606 - val_loss: 0.5140
# Epoch 5/15

# %% [markdown]
# We can see that maximum val_accuracy is ~55%, because the model is too simple and can not detect anomalies.

# %% [markdown]
# # 2. Custom CNNs (initial trials)

# %% [markdown]
# ### A) Non-clahe

# %%
# # Hyperparameter options

# activations = [
#     ("relu", "relu"),
#     ("leakyrelu", LeakyReLU(negative_slope=0.01))
# ]
# conv_base_filters =[32, 64]


# histories_n = []


# for conv_base_filter in conv_base_filters:
#     for activation_name, activation_fn in activations:
#             print(
#                 f"Training model with: "
#                 f"activation={activation_name}, "
#                 f"conv_base_filter={conv_base_filter}"
#             )
        
#             #Apply early stopping to save time & avoid overfitting
#             # Early stopping
#             early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)


#             # Model definition
#             model = Sequential([
#                 Input(shape=(224, 224, 1)),
#                 Conv2D(conv_base_filter, kernel_size=(3,3), activation=activation_fn),
#                 MaxPooling2D(pool_size=(2, 2)),

#                 Conv2D(conv_base_filter*2, kernel_size=(3,3), activation=activation_fn),
#                 MaxPooling2D(pool_size=(2, 2)),

#                 Conv2D(conv_base_filter*4, kernel_size=(3,3), activation=activation_fn),
#                 MaxPooling2D(pool_size=(2, 2)),

#                 Flatten(),
#                 Dense(128, activation=activation_fn),
#                 Dropout(0.5),
#                 Dense(2, activation='softmax')
#             ])

#             # Compile
#             model.compile(
#                 optimizer='adam',
#                 loss='sparse_categorical_crossentropy',
#                 metrics=['accuracy']
#             )

#             # Train
#             history = model.fit(
#                 X_train_non_clahe, y_train_non_clahe,
#                 validation_data=(X_val_non_clahe, y_val_non_clahe),
#                 epochs=30,
#                 batch_size=32,
#                 callbacks=[early_stop]
#             )

#             # Save
#             label = (
#                 f"conv_base_filter={conv_base_filter}, "
#                 f"activation={activation_name} "
#             )
#             histories_n.append((label, history))
# Out:
# Training model with: activation=relu, conv_base_filter=32
# Epoch 1/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 45s 554ms/step - accuracy: 0.6582 - loss: 0.6750 - val_accuracy: 0.7791 - val_loss: 0.5040
# Epoch 2/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 546ms/step - accuracy: 0.7412 - loss: 0.5405 - val_accuracy: 0.7888 - val_loss: 0.4480
# Epoch 3/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 545ms/step - accuracy: 0.7805 - loss: 0.4928 - val_accuracy: 0.7984 - val_loss: 0.4275
# Epoch 4/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 545ms/step - accuracy: 0.7805 - loss: 0.4824 - val_accuracy: 0.8120 - val_loss: 0.3959
# Epoch 5/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 547ms/step - accuracy: 0.7896 - loss: 0.4541 - val_accuracy: 0.7868 - val_loss: 0.4402
# Epoch 6/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 544ms/step - accuracy: 0.8023 - loss: 0.4420 - val_accuracy: 0.8081 - val_loss: 0.4019
# Epoch 7/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 549ms/step - accuracy: 0.8087 - loss: 0.4310 - val_accuracy: 0.7849 - val_loss: 0.4256
# Epoch 8/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 45s 574ms/step - accuracy: 0.8047 - loss: 0.4310 - val_accuracy: 0.8062 - val_loss: 0.4034
# Epoch 9/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 546ms/step - accuracy: 0.8122 - loss: 0.4032 - val_accuracy: 0.8236 - val_loss: 0.3849
# Epoch 10/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 538ms/step - accuracy: 0.8194 - loss: 0.3959 - val_accuracy: 0.8178 - val_loss: 0.3803
# Epoch 11/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 541ms/step - accuracy: 0.8182 - loss: 0.3931 - val_accuracy: 0.8314 - val_loss: 0.3668
# Epoch 12/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 544ms/step - accuracy: 0.8353 - loss: 0.3684 - val_accuracy: 0.8159 - val_loss: 0.3713
# Epoch 13/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 539ms/step - accuracy: 0.8484 - loss: 0.3260 - val_accuracy: 0.8295 - val_loss: 0.3490
# Epoch 14/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 542ms/step - accuracy: 0.8591 - loss: 0.3125 - val_accuracy: 0.8023 - val_loss: 0.4044
# Epoch 15/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 545ms/step - accuracy: 0.8662 - loss: 0.2980 - val_accuracy: 0.8256 - val_loss: 0.3737
# Epoch 16/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 539ms/step - accuracy: 0.8702 - loss: 0.2773 - val_accuracy: 0.8140 - val_loss: 0.4000
# Epoch 17/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 548ms/step - accuracy: 0.8805 - loss: 0.2545 - val_accuracy: 0.8391 - val_loss: 0.3558
# Epoch 18/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 44s 556ms/step - accuracy: 0.8912 - loss: 0.2439 - val_accuracy: 0.8217 - val_loss: 0.4177
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Training model with: activation=leakyrelu, conv_base_filter=32
# Epoch 1/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 47s 587ms/step - accuracy: 0.6558 - loss: 0.6321 - val_accuracy: 0.6744 - val_loss: 0.5849
# Epoch 2/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 583ms/step - accuracy: 0.7447 - loss: 0.5246 - val_accuracy: 0.8023 - val_loss: 0.4397
# Epoch 3/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 586ms/step - accuracy: 0.7936 - loss: 0.4514 - val_accuracy: 0.8217 - val_loss: 0.4069
# Epoch 4/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 584ms/step - accuracy: 0.7916 - loss: 0.4491 - val_accuracy: 0.8062 - val_loss: 0.4146
# Epoch 5/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 586ms/step - accuracy: 0.8031 - loss: 0.4308 - val_accuracy: 0.8236 - val_loss: 0.3912
# Epoch 6/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 585ms/step - accuracy: 0.8059 - loss: 0.4232 - val_accuracy: 0.8217 - val_loss: 0.3804
# Epoch 7/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 585ms/step - accuracy: 0.8202 - loss: 0.3841 - val_accuracy: 0.8140 - val_loss: 0.3945
# Epoch 8/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 584ms/step - accuracy: 0.8333 - loss: 0.3643 - val_accuracy: 0.8333 - val_loss: 0.3656
# Epoch 9/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 584ms/step - accuracy: 0.8456 - loss: 0.3533 - val_accuracy: 0.7984 - val_loss: 0.4261
# Epoch 10/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 583ms/step - accuracy: 0.8563 - loss: 0.3281 - val_accuracy: 0.8411 - val_loss: 0.3523
# Epoch 11/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 586ms/step - accuracy: 0.8714 - loss: 0.3007 - val_accuracy: 0.8236 - val_loss: 0.3625
# Epoch 12/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 584ms/step - accuracy: 0.8785 - loss: 0.2853 - val_accuracy: 0.8236 - val_loss: 0.3699
# Epoch 13/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 47s 590ms/step - accuracy: 0.8912 - loss: 0.2451 - val_accuracy: 0.8159 - val_loss: 0.3581
# Epoch 14/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 585ms/step - accuracy: 0.8988 - loss: 0.2414 - val_accuracy: 0.8159 - val_loss: 0.3675
# Epoch 15/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 46s 587ms/step - accuracy: 0.9178 - loss: 0.2094 - val_accuracy: 0.8353 - val_loss: 0.3803
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Training model with: activation=relu, conv_base_filter=64
# Epoch 1/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.6165 - loss: 0.8006 - val_accuracy: 0.7442 - val_loss: 0.5473
# Epoch 2/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.7491 - loss: 0.5428 - val_accuracy: 0.7461 - val_loss: 0.5012
# Epoch 3/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.7574 - loss: 0.5279 - val_accuracy: 0.8101 - val_loss: 0.4577
# Epoch 4/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.7773 - loss: 0.4818 - val_accuracy: 0.8159 - val_loss: 0.4230
# Epoch 5/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.7940 - loss: 0.4575 - val_accuracy: 0.7984 - val_loss: 0.4110
# Epoch 6/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.7956 - loss: 0.4422 - val_accuracy: 0.8004 - val_loss: 0.4331
# Epoch 7/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.8186 - loss: 0.4247 - val_accuracy: 0.7868 - val_loss: 0.4209
# Epoch 8/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8138 - loss: 0.4113 - val_accuracy: 0.8159 - val_loss: 0.3827
# Epoch 9/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8269 - loss: 0.3831 - val_accuracy: 0.8295 - val_loss: 0.3685
# Epoch 10/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8428 - loss: 0.3607 - val_accuracy: 0.8236 - val_loss: 0.3651
# Epoch 11/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.8563 - loss: 0.3341 - val_accuracy: 0.8411 - val_loss: 0.3417
# Epoch 12/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.8587 - loss: 0.3163 - val_accuracy: 0.8430 - val_loss: 0.3371
# Epoch 13/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.8674 - loss: 0.2943 - val_accuracy: 0.8217 - val_loss: 0.3441
# Epoch 14/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.8714 - loss: 0.2807 - val_accuracy: 0.8314 - val_loss: 0.3631
# Epoch 15/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.8809 - loss: 0.2653 - val_accuracy: 0.8314 - val_loss: 0.3557
# Epoch 16/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9000 - loss: 0.2244 - val_accuracy: 0.8178 - val_loss: 0.3642
# Epoch 17/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9143 - loss: 0.2050 - val_accuracy: 0.8469 - val_loss: 0.4469
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Training model with: activation=leakyrelu, conv_base_filter=64
# Epoch 1/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.6447 - loss: 0.6748 - val_accuracy: 0.6705 - val_loss: 0.6111
# Epoch 2/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.7265 - loss: 0.5514 - val_accuracy: 0.7946 - val_loss: 0.4659
# Epoch 3/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.7825 - loss: 0.4884 - val_accuracy: 0.8120 - val_loss: 0.4184
# Epoch 4/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.7868 - loss: 0.4753 - val_accuracy: 0.8043 - val_loss: 0.4133
# Epoch 5/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.7971 - loss: 0.4501 - val_accuracy: 0.8140 - val_loss: 0.4163
# Epoch 6/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.8051 - loss: 0.4238 - val_accuracy: 0.8062 - val_loss: 0.4097
# Epoch 7/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.8190 - loss: 0.4044 - val_accuracy: 0.8004 - val_loss: 0.3983
# Epoch 8/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.8233 - loss: 0.3909 - val_accuracy: 0.8236 - val_loss: 0.3824
# Epoch 9/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.8273 - loss: 0.3677 - val_accuracy: 0.8101 - val_loss: 0.4060
# Epoch 10/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.8372 - loss: 0.3626 - val_accuracy: 0.8295 - val_loss: 0.3622
# Epoch 11/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.8571 - loss: 0.3260 - val_accuracy: 0.7965 - val_loss: 0.4379
# Epoch 12/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.8634 - loss: 0.3008 - val_accuracy: 0.8120 - val_loss: 0.3816
# Epoch 13/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.8892 - loss: 0.2630 - val_accuracy: 0.8140 - val_loss: 0.3843
# Epoch 14/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.8888 - loss: 0.2489 - val_accuracy: 0.8159 - val_loss: 0.4141
# Epoch 15/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.9063 - loss: 0.2251 - val_accuracy: 0.8333 - val_loss: 0.3997
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# ### B) CLAHE

# %%
# Hyperparameter options

activations = [
    # ("relu", "relu"),
    ("leakyrelu", LeakyReLU(negative_slope=0.01))
]
conv_base_filters =[64]


histories = []


for conv_base_filter in conv_base_filters:
    for activation_name, activation_fn in activations:
            print(
                f"Training model with: "
                f"activation={activation_name}, "
                f"conv_base_filter={conv_base_filter}"
            )
        
            #Apply early stopping to save time & avoid overfitting
            # Early stopping
            early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)


            # Model definition
            model = Sequential([
                Input(shape=(224, 224, 1)),
                Conv2D(conv_base_filter, kernel_size=(3,3), activation=activation_fn),
                MaxPooling2D(pool_size=(2, 2)),

                Conv2D(conv_base_filter*2, kernel_size=(3,3), activation=activation_fn),
                MaxPooling2D(pool_size=(2, 2)),

                Conv2D(conv_base_filter*4, kernel_size=(3,3), activation=activation_fn),
                MaxPooling2D(pool_size=(2, 2)),

                Flatten(),
                Dense(128, activation=activation_fn),
                Dropout(0.5),
                Dense(2, activation='softmax')
            ])

            # Compile
            model.compile(
                optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']
            )

            # Train
            history = model.fit(
                X_train_clahe, y_train_clahe,
                validation_data=(X_val_clahe, y_val_clahe),
                epochs=30,
                batch_size=32,
                callbacks=[early_stop]
            )

            # Save
            label = (
                f"conv_base_filter={conv_base_filter}, "
                f"activation={activation_name} "
            )
            histories.append((label, history))
# Out:
# Training model with: activation=leakyrelu, conv_base_filter=64
# Epoch 1/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 130s 2s/step - accuracy: 0.5713 - loss: 0.7799 - val_accuracy: 0.6003 - val_loss: 0.6690
# Epoch 2/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.6926 - loss: 0.5851 - val_accuracy: 0.7822 - val_loss: 0.5214
# Epoch 3/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.7569 - loss: 0.5149 - val_accuracy: 0.7256 - val_loss: 0.5277
# Epoch 4/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.7765 - loss: 0.4628 - val_accuracy: 0.7890 - val_loss: 0.4939
# Epoch 5/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - accuracy: 0.7830 - loss: 0.4471 - val_accuracy: 0.8010 - val_loss: 0.4919
# Epoch 6/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.8119 - loss: 0.4223 - val_accuracy: 0.7925 - val_loss: 0.5152
# Epoch 7/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.8294 - loss: 0.3974 - val_accuracy: 0.7993 - val_loss: 0.4760
# Epoch 8/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.8327 - loss: 0.3780 - val_accuracy: 0.7856 - val_loss: 0.5069
# Epoch 9/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.8318 - loss: 0.3805 - val_accuracy: 0.7616 - val_loss: 0.5011
# Epoch 10/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.8371 - loss: 0.3793 - val_accuracy: 0.8148 - val_loss: 0.4952
# Epoch 11/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.8453 - loss: 0.3355 - val_accuracy: 0.8027 - val_loss: 0.4919
# Epoch 12/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.8632 - loss: 0.3138 - val_accuracy: 0.8096 - val_loss: 0.4548
# Epoch 13/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.8709 - loss: 0.2986 - val_accuracy: 0.8027 - val_loss: 0.4875
# Epoch 14/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - accuracy: 0.8750 - loss: 0.2837 - val_accuracy: 0.8113 - val_loss: 0.4413
# Epoch 15/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.8950 - loss: 0.2443 - val_accuracy: 0.8370 - val_loss: 0.4436
# Epoch 16/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.8974 - loss: 0.2302 - val_accuracy: 0.8388 - val_loss: 0.4654
# Epoch 17/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.9263 - loss: 0.1814 - val_accuracy: 0.8405 - val_loss: 0.4480
# Epoch 18/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.9275 - loss: 0.1643 - val_accuracy: 0.8302 - val_loss: 0.4992
# Epoch 19/30
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.9401 - loss: 0.1363 - val_accuracy: 0.8302 - val_loss: 0.5312
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %%
for label, history in histories:
    plt.figure(figsize=(40, 8))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Loss '+label)
    plt.plot(history.history['val_loss'], label='Val Loss '+label)
    plt.legend()
    plt.title("Loss over Epochs")
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.legend()
    plt.title("Accuracy over Epochs")
    plt.show()

# %% [markdown]
# After running multiple experiments (see the documents attached on github), the architecture with initial 64 filters and LeakyRelu activation function was selected for fine-tuning. The choice balances model complexity with performance in a practical manner.

# %% [markdown]
# Let us try fine-tuning the model, with changing some parameters and adding small changes that could improve performance.

# %% [markdown]
# # 1. Small changes (different dropouts and initial kernels)

# %% [markdown]
# ### Let us keep a history also for this model adjustments to see the plots

# %%
histories_leaky_64 = []

# %% [markdown]
# And now train the models

# %%
initial_kernels = [(3,3),(5,5)]
dropouts = [0.5, 0.6, 0.7]


for initial_kernel in initial_kernels:
    for dropout in dropouts:
        print(
                f"Training model with: "
                f"initial_kernel={initial_kernel}, "
                f"dropout={dropout}"
            )

        # Early stopping
        early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)


        # Model definition
        model = Sequential([
            Input(shape=(224, 224, 1)),
            Conv2D(64, kernel_size=initial_kernel, activation=(LeakyReLU(negative_slope=0.01))),
            MaxPooling2D(pool_size=(2, 2)),
        
            Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
            MaxPooling2D(pool_size=(2, 2)),
        
            Conv2D(128*2, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
            MaxPooling2D(pool_size=(2, 2)),
        
            Flatten(),
            Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
            Dropout(dropout),
            Dense(3, activation='softmax')
        ])
        
        # Compile
        model.compile(
            optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )
        
        # Train
        history = model.fit(
            X_train_aug, y_train_aug,
            validation_data=(X_val, y_val),
            epochs=30,
            batch_size=32,
            callbacks=[early_stop]
        )
        
        # Save
        label = (
            f"initial_kernel={initial_kernel}, "
            f"dropout={dropout}"
        )
        histories_leaky_64.append((label, history))
# Out:
# Training model with: initial_kernel=(3, 3), dropout=0.5
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.3542 - loss: 1.2225 - val_accuracy: 0.3590 - val_loss: 1.0875
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.4499 - loss: 1.0426 - val_accuracy: 0.5385 - val_loss: 0.9851
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.5393 - loss: 0.9422 - val_accuracy: 0.6752 - val_loss: 0.8301
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6264 - loss: 0.8132 - val_accuracy: 0.5983 - val_loss: 0.8354
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6908 - loss: 0.7221 - val_accuracy: 0.6667 - val_loss: 0.7319
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - accuracy: 0.8098 - loss: 0.4707 - val_accuracy: 0.7094 - val_loss: 0.8072
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.8924 - loss: 0.2918 - val_accuracy: 0.7094 - val_loss: 0.8188
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.9151 - loss: 0.2002 - val_accuracy: 0.7179 - val_loss: 0.8694
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.9465 - loss: 0.1517 - val_accuracy: 0.6838 - val_loss: 1.0500
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - accuracy: 0.9607 - loss: 0.1068 - val_accuracy: 0.7094 - val_loss: 1.0406
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Training model with: initial_kernel=(3, 3), dropout=0.6
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.4066 - loss: 1.2620 - val_accuracy: 0.4701 - val_loss: 1.0185
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.5285 - loss: 0.9471 - val_accuracy: 0.5812 - val_loss: 0.8702
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.6794 - loss: 0.7616 - val_accuracy: 0.6410 - val_loss: 0.7768
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.7608 - loss: 0.5774 - val_accuracy: 0.6923 - val_loss: 0.7078
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 0.8508 - loss: 0.3778 - val_accuracy: 0.6838 - val_loss: 0.7503
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 0.9100 - loss: 0.2394 - val_accuracy: 0.7094 - val_loss: 0.8090
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 0.9408 - loss: 0.1531 - val_accuracy: 0.7094 - val_loss: 0.9017
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 0.9636 - loss: 0.1081 - val_accuracy: 0.6838 - val_loss: 1.1327
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.9789 - loss: 0.0742 - val_accuracy: 0.6923 - val_loss: 1.3651
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Training model with: initial_kernel=(3, 3), dropout=0.7
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.3434 - loss: 1.2164 - val_accuracy: 0.5812 - val_loss: 1.0141
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.4670 - loss: 1.0157 - val_accuracy: 0.2991 - val_loss: 1.2844
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.5860 - loss: 0.8843 - val_accuracy: 0.6325 - val_loss: 0.8187
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.6976 - loss: 0.7092 - val_accuracy: 0.6923 - val_loss: 0.6948
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.7825 - loss: 0.5372 - val_accuracy: 0.7265 - val_loss: 0.6615
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.8702 - loss: 0.3427 - val_accuracy: 0.7179 - val_loss: 0.7141
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.8815 - loss: 0.3117 - val_accuracy: 0.7350 - val_loss: 0.8670
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.9282 - loss: 0.2064 - val_accuracy: 0.7521 - val_loss: 0.7287
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.9493 - loss: 0.1415 - val_accuracy: 0.7265 - val_loss: 0.8972
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.9550 - loss: 0.1165 - val_accuracy: 0.7521 - val_loss: 0.9700
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Training model with: initial_kernel=(5, 5), dropout=0.5
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.3861 - loss: 1.1482 - val_accuracy: 0.5470 - val_loss: 0.9542
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.5883 - loss: 0.8887 - val_accuracy: 0.6496 - val_loss: 0.7839
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.7050 - loss: 0.6894 - val_accuracy: 0.6068 - val_loss: 0.7946
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.8445 - loss: 0.3957 - val_accuracy: 0.6068 - val_loss: 0.9997
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9214 - loss: 0.2216 - val_accuracy: 0.7009 - val_loss: 0.9875
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.9448 - loss: 0.1497 - val_accuracy: 0.7179 - val_loss: 1.1195
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.9618 - loss: 0.1109 - val_accuracy: 0.7521 - val_loss: 0.8980
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Training model with: initial_kernel=(5, 5), dropout=0.6
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.3798 - loss: 1.2539 - val_accuracy: 0.5556 - val_loss: 1.0333
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.4829 - loss: 1.0099 - val_accuracy: 0.5470 - val_loss: 0.9240
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.5501 - loss: 0.9570 - val_accuracy: 0.4103 - val_loss: 0.9672
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.6919 - loss: 0.7397 - val_accuracy: 0.7179 - val_loss: 0.7755
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.7859 - loss: 0.5274 - val_accuracy: 0.7692 - val_loss: 0.6204
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.8741 - loss: 0.3466 - val_accuracy: 0.7607 - val_loss: 0.9597
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9214 - loss: 0.2243 - val_accuracy: 0.7350 - val_loss: 0.9525
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9294 - loss: 0.1756 - val_accuracy: 0.7521 - val_loss: 0.6799
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9567 - loss: 0.1061 - val_accuracy: 0.7350 - val_loss: 1.0810
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9624 - loss: 0.1082 - val_accuracy: 0.7607 - val_loss: 0.8542
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Training model with: initial_kernel=(5, 5), dropout=0.7
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.3559 - loss: 1.2494 - val_accuracy: 0.4188 - val_loss: 1.0769
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.4356 - loss: 1.0638 - val_accuracy: 0.5128 - val_loss: 0.9747
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.5177 - loss: 0.9699 - val_accuracy: 0.5641 - val_loss: 0.9295
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.6281 - loss: 0.8188 - val_accuracy: 0.6838 - val_loss: 0.7675
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.7540 - loss: 0.6187 - val_accuracy: 0.6667 - val_loss: 0.7440
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.8172 - loss: 0.4903 - val_accuracy: 0.7009 - val_loss: 0.7001
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.8793 - loss: 0.3250 - val_accuracy: 0.7179 - val_loss: 0.7788
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9060 - loss: 0.2309 - val_accuracy: 0.6667 - val_loss: 0.8501
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9356 - loss: 0.1738 - val_accuracy: 0.7350 - val_loss: 0.7103
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.9465 - loss: 0.1486 - val_accuracy: 0.7265 - val_loss: 0.7288
# Epoch 11/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.9658 - loss: 0.0966 - val_accuracy: 0.7436 - val_loss: 1.0389
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
for label, history in histories_leaky_128:
    plt.figure(figsize=(40, 8))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Loss '+label)
    plt.plot(history.history['val_loss'], label='Val Loss '+label)
    plt.legend()
    plt.title("Loss over Epochs")
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.legend()
    plt.title("Accuracy over Epochs")
    plt.show()

# %% [markdown]
# We can see that Training model with: initial_kernel=(5, 5), dropout=0.7 provides the best results. Now let us try to improve it with some advanced techniques.

# %% [markdown]
# To identify the optimal architecture, I conducted a grid search over different kernel sizes ((3×3), (5×5)) and dropout rates (0.5, 0.6, 0.7). After multiple runs, the model with an initial kernel size of (5×5) and dropout of 0.7 consistently yielded the highest validation accuracy, achieving a peak of 76.07% at epoch 6 before early stopping

# %%
# Early stopping
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

model_final = Sequential([
        Input(shape=(224, 224, 1)),
        Conv2D(64, kernel_size=(5,5), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(256, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Flatten(),
        Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
        Dropout(0.7),
        Dense(3, activation='softmax')
        ])

# %% [markdown]
# ### Label Smoothing

# %% [markdown]
# Hard one-hot labels (like [0, 1, 0]) encourage the model to become overconfident, especially on small or noisy datasets. This leads to:
# - Overfitting
# - Poor generalization
# - Bad calibration (predicted probabilities are extreme)
#
# Label smoothing combats this by:
# - Penalizing overconfidence
# - Encouraging the model to be a little uncertain
# - Improving generalization,
#
# This is done by apply the formula:
#
# ![1111.PNG](attachment:73e4cac5-8762-42d4-b23b-dbe202ccac8d.PNG)

# %% [markdown]
# Where episilon = smoothing parameter

# %%
num_classes = 3  # Normal, Benign, Malignant
label_smoothing = 0.1

def smooth_labels(y, num_classes, smoothing=0.1):
    """
    Converts sparse labels to smoothed one-hot vectors.
    """
    y_one_hot = tf.one_hot(y, depth=num_classes)
    smooth_positives = 1.0 - smoothing
    smooth_negatives = smoothing / num_classes
    y_smooth = y_one_hot * smooth_positives + smooth_negatives
    return y_smooth

# %%
y_train_smooth = smooth_labels(y_train_aug, num_classes, label_smoothing)
y_val_smooth = smooth_labels(y_val, num_classes, label_smoothing)

# %% [markdown]
# **tf.keras.losses.CategoricalCrossentropydesigned** is used to compute the loss between two probability distributions — the predicted probabilities and the (smoothed) target, from_logits=False because the model ends in softmax.

# %%
loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)
model_final.compile(optimizer='adam', loss=loss, metrics=['accuracy'])

        
# Train
history = model_final.fit(
        X_train_aug, y_train_smooth,
        validation_data=(X_val, y_val_smooth),
        epochs=30,
        batch_size=32,
        callbacks=[early_stop]
        )
# Out:
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.3367 - loss: 1.2223 - val_accuracy: 0.1709 - val_loss: 1.1041
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.4141 - loss: 1.0694 - val_accuracy: 0.4786 - val_loss: 1.0176
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.5273 - loss: 0.9885 - val_accuracy: 0.6154 - val_loss: 0.8596
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.6416 - loss: 0.8714 - val_accuracy: 0.6581 - val_loss: 0.8497
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.7611 - loss: 0.7212 - val_accuracy: 0.6325 - val_loss: 0.8632
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.8441 - loss: 0.6034 - val_accuracy: 0.6752 - val_loss: 0.8100
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.8817 - loss: 0.5423 - val_accuracy: 0.6838 - val_loss: 0.7629
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9340 - loss: 0.4762 - val_accuracy: 0.6410 - val_loss: 0.8153
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9573 - loss: 0.4483 - val_accuracy: 0.7009 - val_loss: 0.7976
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.9653 - loss: 0.4151 - val_accuracy: 0.7350 - val_loss: 0.7706
# Epoch 11/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.9750 - loss: 0.3998 - val_accuracy: 0.7009 - val_loss: 0.7347
# Epoch 12/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9778 - loss: 0.3930 - val_accuracy: 0.7179 - val_loss: 0.7297
# Epoch 13/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9903 - loss: 0.3825 - val_accuracy: 0.7179 - val_loss: 0.7476
# Epoch 14/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9892 - loss: 0.3686 - val_accuracy: 0.7350 - val_loss: 0.7266
# Epoch 15/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.9892 - loss: 0.3742 - val_accuracy: 0.7350 - val_loss: 0.7694
# Epoch 16/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.9932 - loss: 0.3638 - val_accuracy: 0.7350 - val_loss: 0.7299
# Epoch 17/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9892 - loss: 0.3632 - val_accuracy: 0.7179 - val_loss: 0.7435
# Epoch 18/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - accuracy: 0.9949 - loss: 0.3565 - val_accuracy: 0.7436 - val_loss: 0.7363
# Epoch 19/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.9960 - loss: 0.3598 - val_accuracy: 0.7350 - val_loss: 0.7310
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %% [markdown]
# ### Learning Rate Scheduler

# %% [markdown]
# A *Learning Rate Scheduler* is a technique that automatically adjusts the learning rate during training, based on:
# - the number of epochs, or
# - the validation loss/accuracy, or
# - some custom rule
#
# Goal: Improve convergence by using higher learning rates at the beginning (fast learning) and lower learning rates later (fine-tuning).

# %%
# Early stopping
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

model_final = Sequential([
        Input(shape=(224, 224, 1)),
        Conv2D(64, kernel_size=(5,5), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(256, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Flatten(),
        Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
        Dropout(0.7),
        Dense(3, activation='softmax')
        ])

# %% [markdown]
# | Parameter  | Meaning                                                                 | Example                                                         |
# | ---------- | ----------------------------------------------------------------------- | --------------------------------------------------------------- |
# | `monitor`  | The metric to watch (usually `'val_loss'` or `'val_accuracy'`)       | `'val_loss'` means reduce LR if validation loss doesn’t improve |
# | `factor`   | The **multiplicative factor** to reduce the learning rate by            | `factor=0.5` → new LR = old LR × 0.5                            |
# | `patience` | Number of **epochs with no improvement** before reducing LR             | `patience=3` → wait 3 epochs before reducing LR                 |
# | `verbose`  | Whether to print updates                                                | `1` = print when LR changes, `0` = silent                       |
# | `min_lr`   | The **minimum learning rate** the scheduler can reach                   | Prevents LR from going too low (e.g. `1e-6`)                    |

# %%
# Learning rate scheduler
reduce_lr_1 = ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1
)

reduce_lr_2 = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

reduce_lr_3 = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.8,
    patience=5,
    min_lr=1e-6,
    verbose=1
)


# Compile your model
model_final.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## Default

# %%
# Train with callbacks
history = model_final.fit(
    X_train_aug, y_train_aug,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    callbacks=[early_stop, reduce_lr_1]
)
# Out:
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.3436 - loss: 1.1853 - val_accuracy: 0.5641 - val_loss: 1.0556 - learning_rate: 0.0010
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.4539 - loss: 1.0539 - val_accuracy: 0.5641 - val_loss: 0.9938 - learning_rate: 0.0010
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.5421 - loss: 0.9480 - val_accuracy: 0.5983 - val_loss: 0.8504 - learning_rate: 0.0010
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.6451 - loss: 0.8058 - val_accuracy: 0.6752 - val_loss: 0.7490 - learning_rate: 0.0010
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.7486 - loss: 0.5974 - val_accuracy: 0.7350 - val_loss: 0.6792 - learning_rate: 0.0010
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.8504 - loss: 0.3946 - val_accuracy: 0.7009 - val_loss: 0.7968 - learning_rate: 0.0010
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.8999 - loss: 0.2878 - val_accuracy: 0.7179 - val_loss: 0.7270 - learning_rate: 0.0010
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9378 - loss: 0.1944
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.9346 - loss: 0.1984 - val_accuracy: 0.7009 - val_loss: 1.1367 - learning_rate: 0.0010
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.9528 - loss: 0.1359 - val_accuracy: 0.7179 - val_loss: 0.9617 - learning_rate: 5.0000e-04
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.9738 - loss: 0.0824 - val_accuracy: 0.7179 - val_loss: 0.9731 - learning_rate: 5.0000e-04
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %% [markdown]
# ## More aggressive decay

# %%
# Early stopping
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

model_final = Sequential([
        Input(shape=(224, 224, 1)),
        Conv2D(64, kernel_size=(5,5), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(256, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Flatten(),
        Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
        Dropout(0.7),
        Dense(3, activation='softmax')
        ])

# Compile your model
model_final.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train with callbacks
history = model_final.fit(
    X_train_aug, y_train_aug,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    callbacks=[early_stop, reduce_lr_2]
)
# Out:
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.3430 - loss: 1.2078 - val_accuracy: 0.4530 - val_loss: 1.0754 - learning_rate: 0.0010
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.4198 - loss: 1.0687 - val_accuracy: 0.5726 - val_loss: 0.9827 - learning_rate: 0.0010
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.5137 - loss: 0.9721 - val_accuracy: 0.5043 - val_loss: 0.9500 - learning_rate: 0.0010
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.6064 - loss: 0.8463 - val_accuracy: 0.6752 - val_loss: 0.8567 - learning_rate: 0.0010
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.7019 - loss: 0.7024 - val_accuracy: 0.7436 - val_loss: 0.6376 - learning_rate: 0.0010
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.7833 - loss: 0.5369 - val_accuracy: 0.6239 - val_loss: 0.8558 - learning_rate: 0.0010
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.8441 - loss: 0.4049 - val_accuracy: 0.7692 - val_loss: 0.5669 - learning_rate: 0.0010
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.9067 - loss: 0.2586 - val_accuracy: 0.7436 - val_loss: 0.6384 - learning_rate: 0.0010
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9369 - loss: 0.1830
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.9363 - loss: 0.1780 - val_accuracy: 0.7265 - val_loss: 0.6400 - learning_rate: 0.0010
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9556 - loss: 0.1201 - val_accuracy: 0.7265 - val_loss: 0.7864 - learning_rate: 2.0000e-04
# Epoch 11/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9587 - loss: 0.1141
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9579 - loss: 0.1145 - val_accuracy: 0.7350 - val_loss: 0.7999 - learning_rate: 2.0000e-04
# Epoch 12/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9676 - loss: 0.0918 - val_accuracy: 0.7265 - val_loss: 0.8184 - learning_rate: 4.0000e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %% [markdown]
# ## More patient and less aggressive

# %%
# Early stopping
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

model_final = Sequential([
        Input(shape=(224, 224, 1)),
        Conv2D(64, kernel_size=(5,5), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(256, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Flatten(),
        Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
        Dropout(0.7),
        Dense(3, activation='softmax')
        ])

# Compile your model
model_final.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train with callbacks
history = model_final.fit(
    X_train_aug, y_train_aug,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    callbacks=[early_stop, reduce_lr_3]
)
# Out:
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.3641 - loss: 1.1926 - val_accuracy: 0.5812 - val_loss: 1.0493 - learning_rate: 0.0010
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.4556 - loss: 1.0492 - val_accuracy: 0.5470 - val_loss: 1.0153 - learning_rate: 0.0010
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.5210 - loss: 0.9568 - val_accuracy: 0.5983 - val_loss: 0.9013 - learning_rate: 0.0010
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.5967 - loss: 0.8741 - val_accuracy: 0.6496 - val_loss: 0.7719 - learning_rate: 0.0010
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.7304 - loss: 0.6572 - val_accuracy: 0.6410 - val_loss: 0.7458 - learning_rate: 0.0010
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.8197 - loss: 0.4754 - val_accuracy: 0.6838 - val_loss: 0.7599 - learning_rate: 0.0010
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.8692 - loss: 0.3425 - val_accuracy: 0.6752 - val_loss: 0.8501 - learning_rate: 0.0010
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9221 - loss: 0.2185 - val_accuracy: 0.6325 - val_loss: 1.1724 - learning_rate: 0.0010
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9329 - loss: 0.1752 - val_accuracy: 0.6496 - val_loss: 0.9767 - learning_rate: 0.0010
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9517 - loss: 0.1239
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9528 - loss: 0.1183 - val_accuracy: 0.6923 - val_loss: 1.2238 - learning_rate: 0.0010
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %% [markdown]
# ### Cosine Annealing (Special Type of Learning Rate Scheduler)

# %% [markdown]
# Cosine Annealing is a learning rate scheduler that gradually decreases the learning rate following a cosine curve.

# %%
# Early stopping
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

model_final = Sequential([
        Input(shape=(224, 224, 1)),
        Conv2D(64, kernel_size=(5,5), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(256, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Flatten(),
        Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
        Dropout(0.7),
        Dense(3, activation='softmax')
        ])

# %%
# Base setup
lr_schedule_1 = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-3,
    decay_steps=30 * len(X_train_aug),  # for 30 epochs
    alpha=1e-5
)

# Slower decay (higher alpha)
lr_schedule_2 = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-3,
    decay_steps=30 * len(X_train_aug),
    alpha=0.1  # final LR = 10% of initial
)

# Start slower but decay more
lr_schedule_3 = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=5e-4,
    decay_steps=30 * len(X_train_aug),
    alpha=0.01
)

# Decay slower, over more steps
lr_schedule_4 = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-3,
    decay_steps=40 * len(X_train_aug),  # longer decay
    alpha=1e-5
)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule_1)

# Compile 
model_final.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
 
# Train
history = model_final.fit(
    X_train_aug, y_train_aug,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.3549 - loss: 1.1847 - val_accuracy: 0.5641 - val_loss: 1.0445
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.4005 - loss: 1.0835 - val_accuracy: 0.5983 - val_loss: 0.9883
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.5017 - loss: 1.0069 - val_accuracy: 0.6068 - val_loss: 0.8393
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.5899 - loss: 0.8756 - val_accuracy: 0.6838 - val_loss: 0.7642
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.6689 - loss: 0.7445 - val_accuracy: 0.6838 - val_loss: 0.7679
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.8015 - loss: 0.5002 - val_accuracy: 0.7094 - val_loss: 0.7470
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.8720 - loss: 0.3526 - val_accuracy: 0.7094 - val_loss: 0.7082
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9141 - loss: 0.2455 - val_accuracy: 0.7094 - val_loss: 0.8624
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9278 - loss: 0.1959 - val_accuracy: 0.7179 - val_loss: 0.6825
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9551 - loss: 0.1394 - val_accuracy: 0.7607 - val_loss: 0.7396
# Epoch 11/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9613 - loss: 0.1140 - val_accuracy: 0.7436 - val_loss: 1.1881
# Epoch 12/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9647 - loss: 0.1142 - val_accuracy: 0.7436 - val_loss: 0.7238
# Epoch 13/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9693 - loss: 0.1011 - val_accuracy: 0.7521 - val_loss: 0.8049
# Epoch 14/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9755 - loss: 0.0739 - val_accuracy: 0.7094 - val_loss: 1.3461
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
# Early stopping
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

model_final = Sequential([
        Input(shape=(224, 224, 1)),
        Conv2D(64, kernel_size=(5,5), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(256, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Flatten(),
        Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
        Dropout(0.7),
        Dense(3, activation='softmax')
        ])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule_2)

# Compile
model_final.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
 
# Train
history = model_final.fit(
    X_train_aug, y_train_aug,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.3601 - loss: 1.2212 - val_accuracy: 0.5556 - val_loss: 1.0730
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.4619 - loss: 1.0333 - val_accuracy: 0.4872 - val_loss: 0.9565
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.5421 - loss: 0.9341 - val_accuracy: 0.5556 - val_loss: 0.8842
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.6638 - loss: 0.7708 - val_accuracy: 0.6667 - val_loss: 0.7448
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.7645 - loss: 0.5982 - val_accuracy: 0.7094 - val_loss: 0.8014
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.8527 - loss: 0.3826 - val_accuracy: 0.6325 - val_loss: 0.7200
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9044 - loss: 0.2570 - val_accuracy: 0.6923 - val_loss: 0.7959
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9369 - loss: 0.1807 - val_accuracy: 0.7265 - val_loss: 0.7606
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9579 - loss: 0.1237 - val_accuracy: 0.7009 - val_loss: 1.2710
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9585 - loss: 0.1054 - val_accuracy: 0.6838 - val_loss: 1.3709
# Epoch 11/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9681 - loss: 0.0890 - val_accuracy: 0.7094 - val_loss: 1.0640
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
# Early stopping
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

model_final = Sequential([
        Input(shape=(224, 224, 1)),
        Conv2D(64, kernel_size=(5,5), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(256, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Flatten(),
        Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
        Dropout(0.7),
        Dense(3, activation='softmax')
        ])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule_3)

# Compile
model_final.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
 
# Train
history = model_final.fit(
    X_train_aug, y_train_aug,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.3544 - loss: 1.1239 - val_accuracy: 0.5128 - val_loss: 1.0665
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.5228 - loss: 0.9835 - val_accuracy: 0.6410 - val_loss: 0.9246
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.6638 - loss: 0.7708 - val_accuracy: 0.6838 - val_loss: 0.8120
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.7850 - loss: 0.5575 - val_accuracy: 0.6496 - val_loss: 0.6975
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.8641 - loss: 0.3731 - val_accuracy: 0.6239 - val_loss: 0.8539
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9078 - loss: 0.2459 - val_accuracy: 0.7094 - val_loss: 0.7547
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.9397 - loss: 0.1813 - val_accuracy: 0.7436 - val_loss: 0.7360
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.9562 - loss: 0.1315 - val_accuracy: 0.7009 - val_loss: 0.9841
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9659 - loss: 0.1070 - val_accuracy: 0.6838 - val_loss: 1.0871
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
# Early stopping
early_stop = EarlyStopping(patience=5, restore_best_weights=True,monitor='val_loss', verbose=1)

model_final = Sequential([
        Input(shape=(224, 224, 1)),
        Conv2D(64, kernel_size=(5,5), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(128, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Conv2D(256, kernel_size=(3,3), activation=(LeakyReLU(negative_slope=0.01))),
        MaxPooling2D(pool_size=(2, 2)),
    
        Flatten(),
        Dense(128, activation=(LeakyReLU(negative_slope=0.01))),
        Dropout(0.7),
        Dense(3, activation='softmax')
        ])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule_4)

# Compile
model_final.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
 
# Train
history = model_final.fit(
    X_train_aug, y_train_aug,
    validation_data=(X_val, y_val),
    epochs=40,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.3504 - loss: 1.3273 - val_accuracy: 0.5556 - val_loss: 1.0411
# Epoch 2/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.3709 - loss: 1.0917 - val_accuracy: 0.5983 - val_loss: 1.0143
# Epoch 3/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.4784 - loss: 1.0229 - val_accuracy: 0.5641 - val_loss: 0.9324
# Epoch 4/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.5176 - loss: 1.0002 - val_accuracy: 0.4957 - val_loss: 0.9944
# Epoch 5/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.5620 - loss: 0.9123 - val_accuracy: 0.6068 - val_loss: 0.8251
# Epoch 6/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.6013 - loss: 0.8413 - val_accuracy: 0.6410 - val_loss: 0.7810
# Epoch 7/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.7008 - loss: 0.6888 - val_accuracy: 0.6752 - val_loss: 0.7183
# Epoch 8/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.7850 - loss: 0.5038 - val_accuracy: 0.6923 - val_loss: 0.6761
# Epoch 9/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.8510 - loss: 0.3930 - val_accuracy: 0.7265 - val_loss: 0.6649
# Epoch 10/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.8925 - loss: 0.2906 - val_accuracy: 0.7607 - val_loss: 0.8008
# Epoch 11/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9192 - loss: 0.2258 - val_accuracy: 0.7179 - val_loss: 0.6901
# Epoch 12/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.9334 - loss: 0.1835 - val_accuracy: 0.7094 - val_loss: 1.0475
# Epoch 13/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9425 - loss: 0.1666 - val_accuracy: 0.7521 - val_loss: 0.8576
# Epoch 14/40
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9556 - loss: 0.1185 - val_accuracy: 0.7521 - val_loss: 1.0443
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %% [markdown]
# ## Final choices

# %% [markdown]
# We have 4 choices:
#
#     - 1. simple model_final
#
#     - 2. model_final with aggressive decay
#
#     - 3. model_final with lr_schedule_1 = tf.keras.optimizers.schedules.CosineDecay(
#     initial_learning_rate=1e-3,
#     decay_steps=30 * len(X_train_aug),  # for 30 epochs
#     alpha=1e-5)
#
#     - 4. model_final with lr_schedule_4 = tf.keras.optimizers.schedules.CosineDecay(
#     initial_learning_rate=1e-3,
#     decay_steps=40 * len(X_train_aug),  # longer decay
#     alpha=1e-5
# )

# %% [markdown]
# Although Model 2 had slightly better validation accuracy and lower loss, all 4 models reached comparable performance levels. Therefore, further evaluation using metrics such as precision, recall, F1-score, and confusion matrix was conducted to ensure fairness and robustness, especially considering the clinical importance of avoiding false negatives. -> see the next notebook
